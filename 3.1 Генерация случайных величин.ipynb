# %%
import numpy as np             # библиотека для матриц и математики
import pandas as pd            # библиотека для работы с табличками
from scipy import stats        # модуль для работы со статистикой

# библиотеки для визуализации
import matplotlib.pyplot as plt  # для простейших визуализаций
import seaborn as sns            # для более сложных визуализаций

plt.style.use('ggplot')         # стиль графиков
# %matplotlib inline              # все картинки должны рисоваться в питоновской тетрадке без вызова доп команды show

# %%
norm_rv = stats.norm(loc=0,scale=1)
